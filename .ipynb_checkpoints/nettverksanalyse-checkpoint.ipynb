# %% [markdown]
# # Nettverksanalyse i sgis
# https://github.com/statisticsnorway/ssb-sgis
#
# Åpne heller notebooken her: https://nbviewer.org/github/statisticsnorway/intro_til_geopandas/blob/main/nettverksanalyse.ipynb

# %%
# midlrertidig pga noen lokale endringer i pakka
import os
while "ssb-sgis" not in os.listdir():
    os.chdir("..")
os.chdir("ssb-sgis/src")
os.listdir()
# Out:
# ['sgis']

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import sgis as sg

# %% [markdown]
# ## Hente data
#
# Henter data for veger og bygningspunkter i Oslo og to nabokommuner (Bærum og Nordre follo).

# %%
kartdata = "ssb-prod-kart-data-delt/kartdata_analyse/klargjorte-data"

veger = sg.read_geopandas(
    f"{kartdata}/2022/NVDB_ruteplan_nettverk_p20220703_v1.parquet",
    filters=[("KOMMUNENR", "in", ('0301', '3024', '3020'))]
     )

veger = veger[["oneway", "drivetime_fw", "drivetime_bw", "roadid", "KOMMUNENR", "geometry"]]

veger
# Out:
#         oneway  drivetime_fw  drivetime_bw    roadid KOMMUNENR  \
# 119702       B      0.216611      0.216611    {S944}      0301
# 189106       B      0.087743      0.087743  {P99633}      3020
# 189109       B      0.124622      0.124622   {P5300}      3020
# 189277       B      0.107511      0.107511   {K6100}      3020
# 189278       B      0.057101      0.057101   {K6100}      3020
# ...        ...           ...           ...       ...       ...
# 1944347      B      0.175876      0.175876  {P91422}      0301
# 1948011      B      0.111139      0.111139   {P2050}      3020
# 1948017      B      0.136247      0.136247   {P4900}      3020
# 1948023      B      0.108602      0.108602   {P4900}      3020
# 1948029      B      0.114736      0.114736   {P4700}      3020
#
#                                                   geometry
# 119702   MULTILINESTRING Z ((258028.440 6674249.890 413...
# 189106   MULTILINESTRING Z ((267535.900 6626904.300 125...
# 189109   MULTILINESTRING Z ((267234.416 6629037.819 140...
# 189277   MULTILINESTRING Z ((271502.710 6620482.300 157...
# 189278   MULTILINESTRING Z ((271476.937 6620508.594 154...
# ...                                                    ...
# 1944347  MULTILINESTRING Z ((260762.830 6650240.620 43....
# 1948011  MULTILINESTRING Z ((266108.070 6626317.900 130...
# 1948017  MULTILINESTRING Z ((267013.150 6627652.210 151...
# 1948023  MULTILINESTRING Z ((267013.150 6627652.210 151...
# 1948029  MULTILINESTRING Z ((267072.520 6627474.740 138...
#
# [119300 rows x 6 columns]

# %%
aar = 2022

bygningspunktsti = f"ssb-prod-kart-data-delt/kartdata_analyse/klargjorte-data/{aar}/SMAT_bygg_punkt_p{aar}_v1.parquet"

bygg = sg.read_geopandas(
    bygningspunktsti,
    filters=[("KOMMUNENR", "in", ('0301', '3024', '3020'))],
    columns=["KOMMUNENR", "BYGTYPE", "AREAL_E2", "DATOMERGE", "geometry"]
)

bygg["aar"] = bygg.DATOMERGE.map(lambda x: int(x[:4].replace(" ", "0")))

bygg
# Out:
#         KOMMUNENR BYGTYPE  AREAL_E2 DATOMERGE                        geometry  \
# 2126288      3020     181      33.0  20080101  POINT (269263.000 6617407.000)
# 2126460      3020     113      92.0            POINT (267831.000 6616413.000)
# 2126732      3020     181      33.0            POINT (270268.000 6617244.000)
# 2126740      3020     241     115.0  18700101  POINT (268989.000 6617320.000)
# 2126749      3020     181      17.0            POINT (269058.000 6617321.000)
# ...           ...     ...       ...       ...                             ...
# 2704094      0301     161      59.0  19010101  POINT (258558.000 6667933.000)
# 2704589      0301     161      59.0  19010101  POINT (258492.000 6667941.000)
# 2704605      0301     183      31.0  19010101  POINT (258532.000 6668042.000)
# 2704777      0301     181      33.0  19931123  POINT (256610.000 6668631.000)
# 2704846      0301     181      33.0  19931123  POINT (256158.000 6668920.000)
#
#           aar
# 2126288  2008
# 2126460     0
# 2126732     0
# 2126740  1870
# 2126749     0
# ...       ...
# 2704094  1901
# 2704589  1901
# 2704605  1901
# 2704777  1993
# 2704846  1993
#
# [218821 rows x 6 columns]

# %%
origins = bygg.sample(1000)

origins.index = np.arange(0, 1000)

origins
# Out:
#     KOMMUNENR BYGTYPE  AREAL_E2 DATOMERGE                        geometry  \
# 0        3024     111      59.0  18420115  POINT (245133.000 6653902.000)
# 1        0301     111     130.0  19870710  POINT (271714.000 6652139.000)
# 2        3020     181      33.0            POINT (270852.000 6631962.000)
# 3        0301     121      54.0  20100811  POINT (257025.000 6652145.000)
# 4        0301     181      33.0  19010101  POINT (262030.000 6651322.000)
# ..        ...     ...       ...       ...                             ...
# 995      3024     131      60.0  19830815  POINT (249127.000 6653042.000)
# 996      0301     131      60.0  19780301  POINT (257751.000 6650594.000)
# 997      3024     181    1048.0  19811215  POINT (248739.000 6652049.000)
# 998      3024     181      42.0  19970219  POINT (247899.000 6647412.000)
# 999      3020     111     158.0  20130425  POINT (271573.000 6620471.000)
#
#       aar
# 0    1842
# 1    1987
# 2       0
# 3    2010
# 4    1901
# ..    ...
# 995  1983
# 996  1978
# 997  1981
# 998  1997
# 999  2013
#
# [1000 rows x 6 columns]

# %%
destinations = bygg.sample(1000)

destinations.index = np.arange(1000, 2000)

destinations
# Out:
#      KOMMUNENR BYGTYPE  AREAL_E2 DATOMERGE                        geometry  \
# 1000      3020     181      20.0  19950728  POINT (264092.000 6634217.000)
# 1001      3024     182      16.0            POINT (243959.000 6647993.000)
# 1002      3024     181      46.0  20001128  POINT (247435.000 6646747.000)
# 1003      0301     181     228.0  19870202  POINT (271939.000 6651395.000)
# 1004      0301     181      41.0  19900903  POINT (265422.000 6644008.000)
# ...        ...     ...       ...       ...                             ...
# 1995      0301     131      64.0  19800901  POINT (264686.000 6641014.000)
# 1996      0301     111      62.0  19390101  POINT (256485.000 6654675.000)
# 1997      3024     181      33.0            POINT (248526.000 6653844.000)
# 1998      3020     112      95.0  19970910  POINT (266256.000 6625656.000)
# 1999      3020     181      38.0            POINT (269065.000 6627653.000)
#
#        aar
# 1000  1995
# 1001     0
# 1002  2000
# 1003  1987
# 1004  1990
# ...    ...
# 1995  1980
# 1996  1939
# 1997     0
# 1998  1997
# 1999     0
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## Gjør klar til nettverksanalyse
# Man starter med å lage et "nettverk" og regler for analysen. Sp putter man det i NetworkAnalysis-klassen.

# %%
nw = (
    sg.DirectedNetwork(veger)
    .remove_isolated()
    .make_directed_network_norway()
)

rules = sg.NetworkAnalysisRules(weight="minutes")

nwa = sg.NetworkAnalysis(network=nw, rules=rules)

nwa
# Out:
# NetworkAnalysis(
#     network=DirectedNetwork(9522 km, percent_bidirectional=85),
#     rules=NetworkAnalysisRules(weight=minutes, search_tolerance=250, search_factor=0, split_lines=False, ...),
#     log=True, detailed_log=True,
# )

# %% [markdown]
# ## Finn rutefrekvens

# %%
frequencies = nwa.get_route_frequencies(origins.sample(15), destinations.sample(15))

sg.qtm(
    sg.buff(frequencies, 15),
    "frequency",
    scheme="naturalbreaks",
    cmap="plasma",
    title="Antall ganger hver vei ble brukt",
)

frequencies.sort_values("frequency", ascending=False).head(3)
# Out:
#        KOMMUNENR  connected  drivetime_bw  drivetime_fw  idx_orig      meters  \
# 196914      0301        1.0          -1.0           NaN   1516130  131.523871
# 196912      0301        1.0          -1.0           NaN   1516122    3.382776
# 196910      0301        1.0          -1.0           NaN   1516114    4.038333
#
#          minutes  frequency  n_source  n_target oneway roadid source  \
# 196914  0.113439       53.0         2         3     FT  {E18}  97533
# 196912  0.002918       53.0         2         2     FT  {E18}  97532
# 196910  0.003483       53.0         2         2     FT  {E18}  97531
#
#                                    source_wkt target  \
# 196914   POINT (258636.4400000004 6650360.98)  97535
# 196912  POINT (258638.96600000001 6650358.73)  97533
# 196910  POINT (258641.95999999996 6650356.02)  97532
#
#                                    target_wkt  \
# 196914             POINT (258521.0 6650423.1)
# 196912   POINT (258636.4400000004 6650360.98)
# 196910  POINT (258638.96600000001 6650358.73)
#
#                                                  geometry
# 196914  LINESTRING Z (258636.440 6650360.980 2.645, 25...
# 196912  LINESTRING Z (258638.966 6650358.730 2.667, 25...
# 196910  LINESTRING Z (258641.960 6650356.020 2.685, 25...

# %% [markdown]
# ## Finn raskeste rute

# %%
origin = origins.iloc[[0]]

routes = nwa.get_route(
    origin,
    destinations.sample(15),
)

sg.qtm(origin, routes, title="Raskeste rute fra 1 til 15 adresser")

routes
# Out:
#     origin  destination    minutes  \
# 0        0         1404  18.536170
# 1        0         1251  35.060235
# 2        0         1707  14.796427
# 3        0         1691  47.875127
# 4        0         1767  28.162005
# 5        0         1943  29.960514
# 6        0         1340  38.826881
# 7        0         1775  37.853847
# 8        0         1926  42.057234
# 9        0         1546  21.929149
# 10       0         1660  31.022145
# 11       0         1832  30.660329
# 12       0         1279  13.421992
# 13       0         1514   9.051127
#
#                                              geometry
# 0   MULTILINESTRING Z ((252780.540 6650273.220 50....
# 1   MULTILINESTRING Z ((265473.400 6655233.300 265...
# 2   MULTILINESTRING Z ((250135.590 6647896.930 53....
# 3   MULTILINESTRING Z ((266486.050 6661686.920 253...
# 4   MULTILINESTRING Z ((264387.163 6652813.836 116...
# 5   MULTILINESTRING Z ((264182.588 6643703.979 69....
# 6   MULTILINESTRING Z ((270934.125 6651695.275 166...
# 7   MULTILINESTRING Z ((263686.889 6640079.482 94....
# 8   MULTILINESTRING Z ((266992.600 6632759.500 146...
# 9   MULTILINESTRING Z ((254431.600 6653576.800 150...
# 10  MULTILINESTRING Z ((263022.939 6645575.040 6.3...
# 11  MULTILINESTRING Z ((264718.100 6644508.700 123...
# 12  MULTILINESTRING Z ((252272.920 6649945.570 54....
# 13  MULTILINESTRING Z ((248052.587 6649157.786 27....

# %% [markdown]
# ### Service area

# %%
service_areas = nwa.service_area(
    origin,
    breaks=np.arange(1, 11),
)

sg.qtm(service_areas, "minutes", k=10, title="Veier som kan nås fra 1 adresse innen 1 til 10 minutter", legend=False)

service_areas

# %% [markdown]
# ### Reisetider: OD Cost Matrix

# %%
od = nwa.od_cost_matrix(
    origins,
    destinations,
)
od
# Out:
#         origin  destination    minutes
# 0            0         1000  44.510749
# 1            0         1001        NaN
# 2            0         1002  13.958094
# 3            0         1003  33.604567
# 4            0         1004  30.239784
# ...        ...          ...        ...
# 999995     999         1995  38.039927
# 999996     999         1996  53.997860
# 999997     999         1997  60.936736
# 999998     999         1998  12.904503
# 999999     999         1999  15.508763
#
# [1000000 rows x 3 columns]

# %% [markdown]
# Kolonnene 'origin' og 'destination' bruker index-en til inputene.
#
# Man kan derfor enkelt koble resultatene med dataene:

# %%
origins_joinet = origins.join(od.set_index("origin"))
origins_joinet
# Out:
#     KOMMUNENR BYGTYPE  AREAL_E2 DATOMERGE                        geometry  \
# 0        3024     111      59.0  18420115  POINT (245133.000 6653902.000)
# 0        3024     111      59.0  18420115  POINT (245133.000 6653902.000)
# 0        3024     111      59.0  18420115  POINT (245133.000 6653902.000)
# 0        3024     111      59.0  18420115  POINT (245133.000 6653902.000)
# 0        3024     111      59.0  18420115  POINT (245133.000 6653902.000)
# ..        ...     ...       ...       ...                             ...
# 999      3020     111     158.0  20130425  POINT (271573.000 6620471.000)
# 999      3020     111     158.0  20130425  POINT (271573.000 6620471.000)
# 999      3020     111     158.0  20130425  POINT (271573.000 6620471.000)
# 999      3020     111     158.0  20130425  POINT (271573.000 6620471.000)
# 999      3020     111     158.0  20130425  POINT (271573.000 6620471.000)
#
#       aar  destination    minutes
# 0    1842         1000  44.510749
# 0    1842         1001        NaN
# 0    1842         1002  13.958094
# 0    1842         1003  33.604567
# 0    1842         1004  30.239784
# ..    ...          ...        ...
# 999  2013         1995  38.039927
# 999  2013         1996  53.997860
# 999  2013         1997  60.936736
# 999  2013         1998  12.904503
# 999  2013         1999  15.508763
#
# [1000000 rows x 8 columns]

# %%
destinations_joinet = destinations.join(od.set_index("destination"))
destinations_joinet
# Out:
#      KOMMUNENR BYGTYPE  AREAL_E2 DATOMERGE                        geometry  \
# 1000      3020     181      20.0  19950728  POINT (264092.000 6634217.000)
# 1000      3020     181      20.0  19950728  POINT (264092.000 6634217.000)
# 1000      3020     181      20.0  19950728  POINT (264092.000 6634217.000)
# 1000      3020     181      20.0  19950728  POINT (264092.000 6634217.000)
# 1000      3020     181      20.0  19950728  POINT (264092.000 6634217.000)
# ...        ...     ...       ...       ...                             ...
# 1999      3020     181      38.0            POINT (269065.000 6627653.000)
# 1999      3020     181      38.0            POINT (269065.000 6627653.000)
# 1999      3020     181      38.0            POINT (269065.000 6627653.000)
# 1999      3020     181      38.0            POINT (269065.000 6627653.000)
# 1999      3020     181      38.0            POINT (269065.000 6627653.000)
#
#        aar  origin    minutes
# 1000  1995       0  44.510749
# 1000  1995       1  31.087898
# 1000  1995       2  22.489104
# 1000  1995       3  35.472098
# 1000  1995       4  30.200360
# ...    ...     ...        ...
# 1999     0     995  51.911490
# 1999     0     996  37.776692
# 1999     0     997  49.150859
# 1999     0     998  47.266158
# 1999     0     999  15.508763
#
# [1000000 rows x 8 columns]

# %% [markdown]
# Eller gi punktene kolonner med aggregerte data:

# %%
origins["minutes_mean"] = od.groupby("origin").minutes.mean()
origins["minutes_max"] = od.groupby("origin").minutes.max()
origins
# Out:
#     KOMMUNENR BYGTYPE  AREAL_E2 DATOMERGE                        geometry  \
# 0        3024     111      59.0  18420115  POINT (245133.000 6653902.000)
# 1        0301     111     130.0  19870710  POINT (271714.000 6652139.000)
# 2        3020     181      33.0            POINT (270852.000 6631962.000)
# 3        0301     121      54.0  20100811  POINT (257025.000 6652145.000)
# 4        0301     181      33.0  19010101  POINT (262030.000 6651322.000)
# ..        ...     ...       ...       ...                             ...
# 995      3024     131      60.0  19830815  POINT (249127.000 6653042.000)
# 996      0301     131      60.0  19780301  POINT (257751.000 6650594.000)
# 997      3024     181    1048.0  19811215  POINT (248739.000 6652049.000)
# 998      3024     181      42.0  19970219  POINT (247899.000 6647412.000)
# 999      3020     111     158.0  20130425  POINT (271573.000 6620471.000)
#
#       aar  minutes_mean  minutes_max
# 0    1842     27.626412    63.400963
# 1    1987     22.541872    49.978111
# 2       0     33.834414    56.531803
# 3    2010     19.731688    54.362312
# 4    1901     17.579257    49.090574
# ..    ...           ...          ...
# 995  1983     26.131474    64.152717
# 996  1978     17.023718    50.017919
# 997  1981     25.020109    61.392086
# 998  1997     23.967783    59.507385
# 999  2013     43.804084    67.340800
#
# [1000 rows x 8 columns]

# %%
sg.explore(origins, "minutes_mean", scheme="quantiles")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70fe3a1c13b033b1966122229ff1319d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70fe3a1c13b033b1966122229ff1319d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70fe3a1c13b033b1966122229ff1319d = L.map(
#                 &quot;map_70fe3a1c13b033b1966122229ff1319d&quot;,
#                 {
#                     center: [59.8754123309482, 10.662531044310589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_70fe3a1c13b033b1966122229ff1319d);
#
#
#
#
#
#             var tile_layer_695314f087f0754554fb47f10da8f98c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_70fe3a1c13b033b1966122229ff1319d);
#
#
#             map_70fe3a1c13b033b1966122229ff1319d.fitBounds(
#                 [[59.64527520366151, 10.351887241140053], [60.10554945823489, 10.973174847481124]],
#                 {}
#             );
#
#
#             var feature_group_88907244bb7214e9be92ee606aeca9b7 = L.featureGroup(
#                 {}
#             ).addTo(map_70fe3a1c13b033b1966122229ff1319d);
#
#
#         function geo_json_0ca3021907718763682c11b05254e9bb_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;6&quot;: case &quot;14&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;55&quot;: case &quot;59&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;72&quot;: case &quot;79&quot;: case &quot;84&quot;: case &quot;85&quot;: case &quot;88&quot;: case &quot;89&quot;: case &quot;90&quot;: case &quot;97&quot;: case &quot;98&quot;: case &quot;100&quot;: case &quot;101&quot;: case &quot;104&quot;: case &quot;110&quot;: case &quot;113&quot;: case &quot;115&quot;: case &quot;119&quot;: case &quot;120&quot;: case &quot;122&quot;: case &quot;126&quot;: case &quot;130&quot;: case &quot;136&quot;: case &quot;138&quot;: case &quot;143&quot;: case &quot;147&quot;: case &quot;151&quot;: case &quot;175&quot;: case &quot;176&quot;: case &quot;178&quot;: case &quot;184&quot;: case &quot;185&quot;: case &quot;187&quot;: case &quot;192&quot;: case &quot;202&quot;: case &quot;207&quot;: case &quot;208&quot;: case &quot;224&quot;: case &quot;228&quot;: case &quot;235&quot;: case &quot;236&quot;: case &quot;240&quot;: case &quot;274&quot;: case &quot;275&quot;: case &quot;278&quot;: case &quot;281&quot;: case &quot;292&quot;: case &quot;303&quot;: case &quot;306&quot;: case &quot;309&quot;: case &quot;310&quot;: case &quot;311&quot;: case &quot;312&quot;: case &quot;320&quot;: case &quot;326&quot;: case &quot;327&quot;: case &quot;342&quot;: case &quot;343&quot;: case &quot;344&quot;: case &quot;349&quot;: case &quot;355&quot;: case &quot;356&quot;: case &quot;357&quot;: case &quot;361&quot;: case &quot;363&quot;: case &quot;371&quot;: case &quot;373&quot;: case &quot;376&quot;: case &quot;377&quot;: case &quot;378&quot;: case &quot;388&quot;: case &quot;392&quot;: case &quot;394&quot;: case &quot;409&quot;: case &quot;414&quot;: case &quot;415&quot;: case &quot;419&quot;: case &quot;424&quot;: case &quot;425&quot;: case &quot;428&quot;: case &quot;429&quot;: case &quot;431&quot;: case &quot;435&quot;: case &quot;436&quot;: case &quot;441&quot;: case &quot;451&quot;: case &quot;453&quot;: case &quot;458&quot;: case &quot;466&quot;: case &quot;492&quot;: case &quot;500&quot;: case &quot;505&quot;: case &quot;509&quot;: case &quot;512&quot;: case &quot;520&quot;: case &quot;521&quot;: case &quot;523&quot;: c

# %% [markdown]
# Hvis man vil bruke en kolonne som id-er heller enn index-en, kan man sette index-en inni funksjonen:

# %%
od = nwa.od_cost_matrix(
    origins.set_index("KOMMUNENR"),
    destinations,
)
od

# %%
od.groupby("origin").mean()

# %%
od = nwa.od_cost_matrix(
    origins.sample(1),
    origins,
    lines=True
)

sg.qtm(od, "minutes", title="Reisetid fra 1 til 1000 adresser", scheme="quantiles")

# %% [markdown]
# ## Finn raskeste k ruter

# %%
p1, p2 = origins.iloc[[0]], destinations.iloc[[0]]

k_routes = nwa.get_k_routes(p1, p2, k=10, drop_middle_percent=1)

sg.qtm(k_routes, "k")

k_routes

# %% [markdown]
# Sjekk loggen

# %%
nwa.log
